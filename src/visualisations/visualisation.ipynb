# %%
from plotting_metrics_epoch import plot_metrics_epoch
import pandas as pd

metrics_list = ['accuracy', 'f1', 'loss']
metrics_df = pd.read_csv('/home/nstaehel/IPEO_hurricane_assesment/logs/csv-alexnet-adam-0.01/version_0/metrics.csv')
plot_metrics_epoch(metrics_df, metrics=metrics_list, save_path='/home/nstaehel/IPEO_hurricane_assesment/logs/plots/alexnet-adam-metrics.png')
